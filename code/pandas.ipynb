# %%
import numpy as np
import pandas as pd
import glob

# %%
path = './unsplashed/'
documents = ['photos', 'keywords', 'collections', 'conversions', 'colors']
datasets = {}

for doc in documents:
  files = glob.glob(path + doc + ".tsv*")

  subsets = []
  for filename in files:
    df = pd.read_csv(filename, sep='\t', header=0)
    subsets.append(df)

  datasets[doc] = pd.concat(subsets, axis=0, ignore_index=True)

# %%
datasets['photos'].head()
# Out:
#       photo_id                                photo_url  \
# 0  wud-eV6Vpwo  https://unsplash.com/photos/wud-eV6Vpwo
# 1  psIMdj26lgw  https://unsplash.com/photos/psIMdj26lgw
# 2  2EDjes2hlZo  https://unsplash.com/photos/2EDjes2hlZo
# 3  WN8kSLy8KMQ  https://unsplash.com/photos/WN8kSLy8KMQ
# 4  QAXDmkU60OU  https://unsplash.com/photos/QAXDmkU60OU
#
#                                      photo_image_url  \
# 0  https://images.unsplash.com/photo-143924685475...
# 1  https://images.unsplash.com/photo-144077331099...
# 2  https://images.unsplash.com/photo-144683489809...
# 3  https://images.unsplash.com/photo-144530812443...
# 4  https://images.unsplash.com/photo-144196149785...
#
#            photo_submitted_at photo_featured  photo_width  photo_height  \
# 0  2015-08-10 22:48:30.841999              t         4273          2392
# 1  2015-08-28 14:49:40.016052              t         3872          2176
# 2  2015-11-06 18:36:17.334458              t         2560          1707
# ...

# %%
photos = datasets['photos']

# %%
urls = photos['photo_image_url']

# %%
photos['photo_id']
# Out:
# 0        wud-eV6Vpwo
# 1        psIMdj26lgw
# 2        2EDjes2hlZo
# 3        WN8kSLy8KMQ
# 4        QAXDmkU60OU
#             ...
# 24995    eGoU1HxZLUk
# 24996    V5yz9InMF2s
# 24997    6fgxP1VrXwA
# 24998    cZR7HvWy_ms
# 24999    HPHtMOJvHDM
# Name: photo_id, Length: 25000, dtype: object

# %%
urls = photos['photo_image_url']
https://unsplash.com/photos/wud-eV6Vpwo/download?ixid=MnwxMjA3fDB8MXxhbGx8fHx8fHx8fHwxNjgzMTk0ODM0&force=true&w=640

# %%
import urllib.request 
urllib.request.urlretrieve("https://images.unsplash.com/photo-1439246854758-f686a415d9da?ixid=2yJhcHBfaWQiOjEyMDd9&&fm=jpg&w=400&fit=max", "./unsplashed/images/test.png")
# Out:
# ('./unsplashed/images/test.png', <http.client.HTTPMessage at 0x1cc80e7b4c0>)

# %%
for i in range(0,1000):
    urllib.request.urlretrieve(urls[i] + "?ixid=2yJhcHBfaWQiOjEyMDd9&&fm=jpg&w=400&fit=max", "./unsplashed/images/" + str(i) + ".png")
